# %% [markdown]
# Reproduza as visualizações abaixo. Para cada uma, pense em pontos que você poderia modificar na visualização, pensando em aprimorá-la.

# %% [markdown]
# #### Preços médios do etanol e da gasolina, por região do Brasil

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('2004-2021.tsv', sep='\t')
print(df.shape, df.dtypes)
df.head()
# Out:
# (120823, 18) DATA INICIAL                      object
# DATA FINAL                        object
# REGIÃO                            object
# ESTADO                            object
# PRODUTO                           object
# NÚMERO DE POSTOS PESQUISADOS       int64
# UNIDADE DE MEDIDA                 object
# PREÇO MÉDIO REVENDA              float64
# DESVIO PADRÃO REVENDA            float64
# PREÇO MÍNIMO REVENDA             float64
# PREÇO MÁXIMO REVENDA             float64
# MARGEM MÉDIA REVENDA              object
# COEF DE VARIAÇÃO REVENDA         float64
# PREÇO MÉDIO DISTRIBUIÇÃO          object
# DESVIO PADRÃO DISTRIBUIÇÃO        object
# PREÇO MÍNIMO DISTRIBUIÇÃO         object
# PREÇO MÁXIMO DISTRIBUIÇÃO         object
# COEF DE VARIAÇÃO DISTRIBUIÇÃO     object
# dtype: object
#   DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0   2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1   2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# ...

# %%
df['data'] = pd.to_datetime(df['DATA FINAL'])
df[['DATA FINAL', 'data']].head()
# Out:
#    DATA FINAL       data
# 0  2004-05-15 2004-05-15
# 1  2004-05-15 2004-05-15
# 2  2004-05-15 2004-05-15
# 3  2004-05-15 2004-05-15
# 4  2004-05-15 2004-05-15

# %%
df['PRODUTO'].unique()
# Out:
# array(['ETANOL HIDRATADO', 'GASOLINA COMUM', 'GLP', 'GNV', 'ÓLEO DIESEL',
#        'ÓLEO DIESEL S10', 'OLEO DIESEL', 'OLEO DIESEL S10',
#        'GASOLINA ADITIVADA'], dtype=object)

# %%
df_filtrado = df[(df['PRODUTO']=='ETANOL HIDRATADO') | (df['PRODUTO']=='GASOLINA COMUM')]
df_filtrado
# Out:
#        DATA INICIAL  DATA FINAL        REGIÃO              ESTADO  \
# 0        2004-05-09  2004-05-15  CENTRO OESTE    DISTRITO FEDERAL
# 1        2004-05-09  2004-05-15  CENTRO OESTE               GOIAS
# 2        2004-05-09  2004-05-15  CENTRO OESTE         MATO GROSSO
# 3        2004-05-09  2004-05-15  CENTRO OESTE  MATO GROSSO DO SUL
# 4        2004-05-09  2004-05-15      NORDESTE             ALAGOAS
# ...             ...         ...           ...                 ...
# 120721   2021-04-25  2021-05-01         NORTE             RORAIMA
# 120722   2021-04-25  2021-05-01           SUL      SANTA CATARINA
# 120723   2021-04-25  2021-05-01       SUDESTE           SAO PAULO
# 120724   2021-04-25  2021-05-01      NORDESTE             SERGIPE
# 120725   2021-04-25  2021-05-01         NORTE           TOCANTINS
#
#                  PRODUTO  NÚMERO DE POSTOS PESQUISADOS UNIDADE DE MEDIDA  \
# 0       ETANOL HIDRATADO                           127              R$/l
# ...

# %%
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,5))

produtos = ['ETANOL HIDRATADO', 'GASOLINA COMUM']
contador = 1

for produto in produtos:
    plt.subplot(1, 2, contador)
    
    df_produto = df_filtrado[df_filtrado['PRODUTO']==produto]
    produto_agrupado = df_produto.groupby(['data', 'REGIÃO'])['PREÇO MÉDIO REVENDA'].mean().unstack()
    datas = produto_agrupado.index
    
    plt.plot(produto_agrupado)
    
    plt.legend(df['REGIÃO'].unique())
    plt.title(produto)
    plt.ylabel('Preço médio de revenda (R$)')
    plt.xticks(datas[::100], rotation=45)
    
    contador += 1

plt.suptitle('Preço médio de revenda por região')
# Out:
# Text(0.5, 0.98, 'Preço médio de revenda por região')

# %% [markdown]
# #### Preço médio em 2020 dos preços do Etanol e da Gasolina por região

# %%
df_filtrado.groupby(['REGIÃO', 'PRODUTO'])['PREÇO MÉDIO REVENDA'].mean().unstack()
# Out:
# PRODUTO       ETANOL HIDRATADO  GASOLINA COMUM
# REGIÃO
# CENTRO OESTE          2.245860        3.222747
# NORDESTE              2.451679        3.156756
# NORTE                 2.655331        3.284190
# SUDESTE               2.293122        3.161360
# SUL                   2.412379        3.113193

# %% [markdown]
# #### Total consolidado de postos para cada estado

# %% [markdown]
# #### Relação entre preço da gasolina e do etanol (nível Brasil)
